# %%
import sys
sys.path.insert(0, "../lib")
sys.path.insert(0, "../src")

import numpy as np
import tables

from nade import NADE

# %%
def display_fields(F, n_fields=25):
    for i in xrange(n_fields):
        subplot(5, 5, i+1)
        axis('off'); gray()
        imshow(F[i].reshape( (28,28)), interpolation='nearest')

# %%
with tables.openFile("../src/mnist-experiment5.h5", "r") as h5:
    L  = h5.root.L[:]
    LL = h5.root.LL_epoch[:]
    b = h5.root.b[-1,:]
    c = h5.root.c[-1,:]
    W = h5.root.W[-1,:,:]
    V = h5.root.V[-1,:,:]
    #train_x = h5.root.x_train[-1,:]
  
batches = 5000
n_vis, n_hid = W.shape



#ylim([-200, -80])
pc
lot(L, "-", c='gray'); title("Log-Likelihood"); xlabel("SGD step")
plot(np.arange(batches, LL.shape[0]*batches+500, batches), LL, 'x-', c='b', linewidth=2)
print "Last LL:", LL[-1]
# Out:
# ---------------------------------------------------------------------------
# NoSuchNodeError                           Traceback (most recent call last)
# <ipython-input-375-ce77408dd5c4> in <module>()
#       1 with tables.openFile("../src/mnist-experiment5.h5", "r") as h5:
# ----> 2     L  = h5.root.L[:]
#       3     LL = h5.root.LL_epoch[:]
#       4     b = h5.root.b[-1,:]
#       5     c = h5.root.c[-1,:]
#
# /usr/lib/python2.7/dist-packages/tables/group.pyc in __getattr__(self, name)
#     758             self._g_addChildrenNames()
#     759             return myDict[name]
# --> 760         return self._f_getChild(name)
#     761
#     762
#
# /usr/lib/python2.7/dist-packages/tables/group.pyc in _f_getChild(self, childname)
#     637         self._g_checkOpen()
#     638
# --> 639         self._g_checkHasChild(childname)
#     640
#     641         childPath = joinPath(self._v_pathname, childname)
#
# /usr/lib/python2.7/dist-packages/tables/group.pyc in _g_checkHasChild(self, name)
#     372             raise NoSuchNodeError(
#     373                 "group ``%s`` does not have a child named ``%s``"
# --> 374                 % (self._v_pathname, name))
#     375         return node_type
#     376
#
# NoSuchNodeError: group ``/`` does not have a child named ``L``

# %%
display_fields(W.T)

# %%
display_fields(V)

# %%
nade = NADE(n_vis, n_hid)

# %%
nade.W.set_value(W)
nade.V.set_value(V)
nade.b.set_value(b)
nade.c.set_value(c)

# %%
f_sample = nade.f_sample()

# %%
spl = f_sample()
display_fields(spl)
